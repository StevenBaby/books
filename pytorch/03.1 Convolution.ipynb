# %%
# %config InlineBackend.figure_formats = ['svg']

# %%
import sys
sys.path.insert(0, "..")

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from tqdm import tqdm
import datasets

# %%
if torch.cuda.is_available():
    torch.set_default_tensor_type(torch.cuda.FloatTensor)
    print("using cuda:", torch.cuda.get_device_name(0))
else:
    torch.set_default_tensor_type(torch.float32)
    print("using cpu...")
# Out:
# using cuda: NVIDIA GeForce MX150

# %%
class MnistDataset(Dataset):

    def __init__(self, train=True) -> None:
        print("Loading mnist dataset, please wait about 10 seconds...")

        x_train, x_test, t_train, t_test = datasets.load_mnist(shuffle=False)
        if train:
            self.x = torch.tensor(x_train)
            self.t = torch.tensor(t_train)
        else:
            self.x = torch.tensor(x_test)
            self.t = torch.tensor(t_test)

        self.x = self.x.float()
        self.t = self.t.float()

        print("Mnist dataset loaded.")

    def __len__(self):
        return self.x.shape[0]

    def __getitem__(self, index):
        return self.x[index], self.t[index]

    def plot_image(self, index):
        image = self.x[index]
        label = self.t[index]

        if image.is_cuda:
            image = image.cpu()
        if label.is_cuda:
            label = label.cpu()


        ax = plt.figure().add_subplot()
        ax.axis('off')
        ax.text(1, 5, int(torch.argmax(label)), color='k')
        ax.imshow(image.reshape(28, 28), cmap=plt.cm.Blues)

# %%
dataset = MnistDataset()
# Out:
# Loading mnist dataset, please wait about 10 seconds...
# Mnist dataset loaded.

# %%
dataset.plot_image(1)

# %%
class ImageView(nn.Module):

    def forward(self, x: torch.Tensor):
        batch_size = x.shape[0]
        return x.view(batch_size, 1, 28, 28)


class TargetView(nn.Module):

    def __init__(self, weight) -> None:
        super().__init__()
        self.weight = weight

    def forward(self, x: torch.Tensor):
        batch_size = x.shape[0]
        return x.view(batch_size, self.weight)


class Classifier(nn.Module):

    def __init__(self) -> None:
        super().__init__()
        self.model = nn.Sequential(
            ImageView(),
            nn.Conv2d(1, 10, kernel_size=5, stride=2),
            nn.LeakyReLU(),
            nn.BatchNorm2d(10),
            nn.Conv2d(10, 10, kernel_size=3, stride=2),
            nn.LeakyReLU(),
            nn.BatchNorm2d(10),

            TargetView(250),
            nn.Linear(250, 10),
            nn.Sigmoid(),
        )

        # self.loss_function = nn.BCEWithLogitsLoss()
        self.loss_function = nn.BCELoss()
        # self.loss_function = nn.MSELoss()
        self.optimizer = torch.optim.Adam(self.parameters())
        # self.optimizer = torch.optim.SGD(self.parameters(), lr=0.1)

    def forward(self, x):
        return self.model(x)

# %%
def train(net, dataset, batch_size, epoch):
    loss_list = []
    acc_list = []

    bar = tqdm(range(epoch))

    generator = None
    if torch.cuda.is_available():
        generator=torch.Generator(device='cuda')

    for e in bar:

        total = 0
        right = 0

        dataloader = DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=True,
            generator=generator,
        )

        for x, t in dataloader:
            y = net.forward(x)

            loss = net.loss_function(y, t)

            net.optimizer.zero_grad()

            loss.backward()

            net.optimizer.step()

            total += x.shape[0]
            right += torch.sum(
                torch.argmax(y, axis=1) == torch.argmax(t, axis=1)
            )

            acc = right / total * 100

            loss_list.append(loss.item())
            acc_list.append(acc.cpu())
            bar.set_postfix(dict(acc=f"{int(acc)}%", loss=f"{loss.item():0.2}",))
    return acc_list, loss_list

# %%
batch_size = 1000

net = Classifier()

epoch = 200

acc_list, loss_list = train(net, dataset, batch_size, epoch)
# Out:
# 100%|██████████| 200/200 [05:18<00:00,  1.59s/it, acc=98%, loss=0.07]

# %%
fig = plt.figure(figsize=(12, 4))
axes = fig.add_subplot(1, 2, 1)
axes.plot(loss_list, label='loss')
axes = fig.add_subplot(1, 2, 2)
axes.plot(acc_list, label='accuracy')
axes.legend()
plt.show()

# %%
testset = MnistDataset(train=False)
# Out:
# Loading mnist dataset, please wait about 10 seconds...
# Mnist dataset loaded.

# %%
def test(testset):
    right = 0
    total = 0

    dataloader = DataLoader(
        dataset=testset,
        batch_size=batch_size,
    )

    bar = tqdm(dataloader)

    for x, t in bar:
        y = net.forward(x)

        total += x.shape[0]
        right += torch.sum(torch.argmax(y, axis=1) == torch.argmax(t, axis=1))

        acc = right / total * 100

        bar.set_postfix(dict(acc=f"{acc.float():0.3}%",))

# %%
test(testset)
# Out:
# 100%|██████████| 18/18 [00:00<00:00, 24.48it/s, acc=98.7%]
